# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input,Dense,Reshape,Flatten,Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

import os
if not os.path.exists("./gan_images"):
    os.makedirs("./gan_images")

# %%
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

# %%
generator.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 6272)              633472
# _________________________________________________________________
# batch_normalization (BatchNo (None, 6272)              25088
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 7, 128)         0
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 14, 14, 64)        204864
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# activation (Activation)      (None, 14, 14, 64)        0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 1)         1601
# =================================================================
# Total params: 865,281
# Trainable params: 852,609
# Non-trainable params: 12,672
# _________________________________________________________________

# %%
#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

# %%
discriminator.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 14, 14, 64)        1664
# _________________________________________________________________
# activation_1 (Activation)    (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 128)         204928
# _________________________________________________________________
# activation_2 (Activation)    (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6273
# =================================================================
# Total params: 212,865
# Trainable params: 0
# Non-trainable params: 212,865
# _________________________________________________________________

# %%
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 28, 28, 1)         865281
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________

# %%
def gan_train(epoch, batch_size, saving_interval):
    (X_train, _), (_, _)=mnist.load_data()
    X_train=X_train.reshape(X_train.shape[0], 28,28,1).astype('float32')
    X_train=(X_train-127.5)/127.5 #절반을 빼고, 그 절반으로 나누면 -1~1사이의 range로 변환됨
    true=np.ones((batch_size,1))
    fake=np.zeros((batch_size,1))
    for i in range(epoch):
        idx=np.random.randint(0, X_train.shape[0], batch_size)
        imgs=X_train[idx]
        d_loss_real=discriminator.train_on_batch(imgs, true) # 데이터를 학습시키는 부분
        #train_on_batch로 학습 (input, target)
        noise=np.random.normal(0,1,(batch_size,100))  # 0과 1사이로 정규분포 노이즈는 100개 발생시킨다
        gen_imgs=generator.predict(noise)  # 가중치와 바이어스가 랜덤하게 되어 있어서 말도 안되는 그림이 나온다
        d_loss_fake=discriminator.train_on_batch(gen_imgs,fake) # 이렇게 나온 놈은 가짜이다.
        #판별자와 생성자의 오차 계산
        d_loss=0.5*np.add(d_loss_real, d_loss_fake)
        g_loss=gan.train_on_batch(noise,true) # discriminator 학습이 일어나지 않는다. 오직 gan 만 일어난다.
        print('epoch:%d' %i, 'd_loss:%.4f' %d_loss, 'g_loss:%.4f' %g_loss)
        if i % saving_interval == 0:  # 소스를 받은거, 중간 세이브 , 실제 액션은 윗부분
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)
              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5
              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("gan_images/gan_mnist_%d.png" % i)

# %%
gan_train(4001,32,200)
# Out:
# epoch:0 d_loss:0.6970 g_loss:0.5471
# epoch:1 d_loss:0.5308 g_loss:0.2316
# epoch:2 d_loss:0.4808 g_loss:0.0801
# epoch:3 d_loss:0.4624 g_loss:0.0467
# epoch:4 d_loss:0.4716 g_loss:0.0481
# epoch:5 d_loss:0.4487 g_loss:0.0898
# epoch:6 d_loss:0.4461 g_loss:0.1838
# epoch:7 d_loss:0.4569 g_loss:0.2870
# epoch:8 d_loss:0.4346 g_loss:0.3519
# epoch:9 d_loss:0.4449 g_loss:0.3775
# epoch:10 d_loss:0.4407 g_loss:0.3696
# epoch:11 d_loss:0.4261 g_loss:0.3629
# epoch:12 d_loss:0.3936 g_loss:0.3284
# epoch:13 d_loss:0.3803 g_loss:0.2598
# epoch:14 d_loss:0.3646 g_loss:0.1964
# epoch:15 d_loss:0.3065 g_loss:0.1390
# epoch:16 d_loss:0.2338 g_loss:0.0949
# epoch:17 d_loss:0.1655 g_loss:0.0483
# epoch:18 d_loss:0.1153 g_loss:0.0218
# epoch:19 d_loss:0.0994 g_loss:0.0047
# epoch:20 d_loss:0.0465 g_loss:0.0069
# epoch:21 d_loss:0.0683 g_loss:0.0202
# epoch:22 d_loss:0.0845 g_loss:0.0041
# epoch:23 d_loss:0.0759 g_loss:0.0150
# epoch:24 d_loss:0.0533 g_loss:0.0674
# epoch:25 d_loss:0.3739 g_loss:0.0013
# epoch:26 d_loss:0.1688 g_loss:0.1867
# epoch:27 d_loss:0.4388 g_loss:0.0227
# epoch:28 d_loss:0.4910 g_loss:0.9314
# epoch:29 d_loss:0.8813 g_loss:0.0923
# epoch:30 d_loss:0.4082 g_loss:0.8436
# epoch:31 d_loss:0.2081 g_loss:2.0922
# epoch:32 d_loss:0.3056 g_loss:0.2993
# epoch:33 d_loss:0.2912 g_loss:0.4911
# epoch:34 d_loss:0.0755 g_loss:2.2155
# epoch:35 d_loss:0.1609 g_loss:2.0555
# epoch:36 d_loss:0.2011 g_loss:1.6607
# epoch:37 d_loss:0.3529 g_loss:1.1271
# epoch:38 d_loss:0.4531 g_loss:1.2100
# epoch:39 d_loss:0.7225 g_loss:1.2186
# epoch:40 d_loss:0.6856 g_loss:1.4517
# epoch:41 d_loss:0.8740 g_loss:1.1789
# epoch:42 d_loss:0.8271 g_loss:1.4075
# epoch:43 d_loss:0.7765 g_loss:1.3258
# epoch:44 d_loss:0.6005 g_loss:1.8810
# epoch:45 d_loss:0.3698 g_loss:2.4243
# epoch:46 d_loss:0.5470 g_loss:2.3051
# epoch:47 d_loss:0.4140 g_loss:2.0541
# epoch:48 d_loss:0.2787 g_loss:2.2566
# epoch:49 d_loss:0.3030 g_loss:2.1694
# epoch:50 d_loss:0.2546 g_loss:2.3455
# epoch:51 d_loss:0.3340 g_loss:1.9222
# epoch:52 d_loss:0.2626 g_loss:1.5933
# epoch:53 d_loss:0.4241 g_loss:0.8911
# epoch:54 d_loss:0.3084 g_loss:0.5701
# epoch:55 d_loss:0.2814 g_loss:0.5577
# epoch:56 d_loss:0.4216 g_loss:0.3452
# epoch:57 d_loss:0.4789 g_loss:0.3467
# epoch:58 d_loss:0.6611 g_loss:0.2313
# epoch:59 d_loss:0.6907 g_loss:0.3675
# epoch:60 d_loss:0.7791 g_loss:0.5277
# epoch:61 d_loss:0.7362 g_loss:0.4827
# epoch:62 d_loss:0.3039 g_loss:0.7246
# epoch:63 d_loss:0.2094 g_loss:1.2952
# epoch:64 d_loss:0.1888 g_loss:1.8772
# epoch:65 d_loss:0.0641 g_loss:2.5793
# epoch:66 d_loss:0.0707 g_loss:2.6487
# epoch:67 d_loss:0.0955 g_loss:2.7522
# epoch:68 d_loss:0.1379 g_loss:3.2701
# epoch:69 d_loss:0.0675 g_loss:4.1405
# epoch:70 d_loss:0.0879 g_loss:4.1246
# epoch:71 d_loss:0.1539 g_loss:3.8741
# epoch:72 d_loss:0.4303 g_loss:2.0910
# epoch:73 d_loss:0.4378 g_loss:1.4869
# epoch:74 d_loss:0.4206 g_loss:2.0334
# epoch:75 d_loss:0.2562 g_loss:3.1442
# epoch:76 d_loss:0.5188 g_loss:2.1225
# epoch:77 d_loss:0.4295 g_loss:0.9928
# epoch:78 d_loss:0.3466 g_loss:1.2687
# epoch:79 d_loss:0.2557 g_loss:1.6816
# epoch:80 d_loss:0.3595 g_loss:1.5428
# epoch:81 d_loss:0.4829 g_loss:1.1652
# epoch:82 d_loss:0.3874 g_loss:1.4055
# epoch:83 d_loss:0.4167 g_loss:1.4066
# epoch:84 d_loss:0.4664 g_loss:1.0383
# epoch:85 d_loss:0.5712 g_loss:1.0513
# epoch:86 d_loss:0.6620 g_loss:1.2076
# epoch:87 d_loss:0.4475 g_loss:1.5318
# epoch:88 d_loss:0.6767 g_loss:0.9713
# epoch:89 d_loss:0.4535 g_loss:1.4808
# epoch:90 d_loss:0.7927 g_loss:1.3977
# epoch:91 d_loss:1.0400 g_loss:0.9816
# epoch:92 d_loss:0.9876 g_loss:0.8884
# epoch:93 d_loss:0.9115 g_loss:1.1608
# epoch:94 d_loss:1.0351 g_loss:1.1288
# epoch:95 d_loss:0.9968 g_loss:1.0205
# epoch:96 d_loss:0.9645 g_loss:1.0572
# epoch:97 d_loss:0.7414 g_loss:1.0287
# epoch:98 d_loss:0.6974 g_loss:1.1395
# epoch:99 d_loss:0.6373 g_loss:1.0908
# epoch:100 d_loss:0.5690 g_loss:1.0617
# epoch:101 d_loss:0.4480 g_loss:1.2096
# epoch:102 d_loss:0.3893 g_loss:1.2991
# epoch:103 d_loss:0.4112 g_loss:1.4130
# epoch:104 d_loss:0.3956 g_loss:1.4358
# epoch:105 d_loss:0.2564 g_loss:1.4199
# epoch:106 d_loss:0.2248 g_loss:1.5163
# epoch:107 d_loss:0.2408 g_loss:1.5794
# epoch:108 d_loss:0.1756 g_loss:1.8523
# epoch:109 d_loss:0.2326 g_loss:1.9107
# epoch:110 d_loss:0.3344 g_loss:1.8002
# epoch:111 d_loss:0.3194 g_loss:1.4632
# epoch:112 d_loss:0.3960 g_loss:1.7537
# epoch:113 d_loss:0.2869 g_loss:1.7211
# epoch:114 d_loss:0.3340 g_loss:1.8941
# epoch:115 d_loss:0.7003 g_loss:2.3974
# epoch:116 d_loss:0.7615 g_loss:1.5985
# epoch:117 d_loss:0.5732 g_loss:1.7812
# epoch:118 d_loss:0.6401 g_loss:1.3877
# epoch:119 d_loss:0.9475 g_loss:1.3231
# epoch:120 d_loss:1.0758 g_loss:1.6372
# epoch:121 d_loss:0.9903 g_loss:1.5346
# epoch:122 d_loss:1.0153 g_loss:1.1232
# epoch:123 d_loss:0.9168 g_loss:1.3307
# epoch:124 d_loss:0.9494 g_loss:1.2441
# epoch:125 d_loss:0.8200 g_loss:1.3337
# epoch:126 d_loss:0.8525 g_loss:1.0953
# epoch:127 d_loss:0.7775 g_loss:1.1644
# epoch:128 d_loss:0.8881 g_loss:1.0131
# epoch:129 d_loss:0.8524 g_loss:1.1534
# epoch:130 d_loss:0.7246 g_loss:1.2283
# epoch:131 d_loss:0.6756 g_loss:1.3213
# epoch:132 d_loss:0.6535 g_loss:1.3167
# epoch:133 d_loss:0.5960 g_loss:1.2564
# epoch:134 d_loss:0.5227 g_loss:1.1642
# epoch:135 d_loss:0.4558 g_loss:1.2749
# epoch:136 d_loss:0.4805 g_loss:1.3111
# epoch:137 d_loss:0.4363 g_loss:1.3732
# epoch:138 d_loss:0.5120 g_loss:1.3479
# epoch:139 d_loss:0.3893 g_loss:1.3767
# epoch:140 d_loss:0.4228 g_loss:1.3102
# epoch:141 d_loss:0.4296 g_loss:1.4327
# epoch:142 d_loss:0.3060 g_loss:1.5888
# epoch:143 d_loss:0.4164 g_loss:1.2769
# epoch:144 d_loss:0.4229 g_loss:1.1454
# epoch:145 d_loss:0.4989 g_loss:1.3181
# epoch:146 d_loss:0.3204 g_loss:1.4341
# epoch:147 d_loss:0.4792 g_loss:1.2582
# epoch:148 d_loss:0.3243 g_loss:1.3456
# epoch:149 d_loss:0.3474 g_loss:1.3566
# epoch:150 d_loss:0.4231 g_loss:1.2602
# epoch:151 d_loss:0.4763 g_loss:1.1832
# epoch:152 d_loss:0.4980 g_loss:1.0920
# epoch:153 d_loss:0.5075 g_loss:1.1674
# epoch:154 d_loss:0.4771 g_loss:1.2377
# epoch:155 d_loss:0.6869 g_loss:1.3052
# epoch:156 d_loss:0.5984 g_loss:1.0037
# epoch:157 d_loss:0.7776 g_loss:0.9378
# epoch:158 d_loss:0.8092 g_loss:0.7763
# epoch:159 d_loss:0.8520 g_loss:0.9404
# epoch:160 d_loss:0.6089 g_loss:1.0992
# epoch:161 d_loss:0.5472 g_loss:1.3253
# epoch:162 d_loss:0.6509 g_loss:1.3413
# epoch:163 d_loss:0.8257 g_loss:0.9907
# epoch:164 d_loss:0.6922 g_loss:1.0257
# epoch:165 d_loss:0.7778 g_loss:1.0554
# epoch:166 d_loss:0.5875 g_loss:1.0640
# epoch:167 d_loss:0.7388 g_loss:1.0185
# epoch:168 d_loss:0.5628 g_loss:1.3300
# epoch:169 d_loss:0.5758 g_loss:1.3864
# epoch:170 d_loss:0.4928 g_loss:1.5214
# epoch:171 d_loss:0.6876 g_loss:1.5835
# epoch:172 d_loss:0.6537 g_loss:1.3448
# epoch:173 d_loss:0.4168 g_loss:1.7770
# epoch:174 d_loss:0.5669 g_loss:1.8694
# epoch:175 d_loss:0.3835 g_loss:2.1880
# epoch:176 d_loss:0.2950 g_loss:2.5407
# epoch:177 d_loss:0.4666 g_loss:2.5396
# epoch:178 d_loss:0.4562 g_loss:2.4208
# epoch:179 d_loss:0.4414 g_loss:2.1982
# epoch:180 d_loss:0.4289 g_loss:2.2019
# epoch:181 d_loss:0.4348 g_loss:2.2116
# epoch:182 d_loss:0.4535 g_loss:2.5813
# epoch:183 d_loss:0.3660 g_loss:3.4119
# epoch:184 d_loss:0.4537 g_loss:3.2562
# epoch:185 d_loss:0.3938 g_loss:2.8682
# epoch:186 d_loss:0.6326 g_loss:2.4420
# epoch:187 d_loss:0.5421 g_loss:2.1137
# epoch:188 d_loss:0.6330 g_loss:1.9035
# epoch:189 d_loss:0.5894 g_loss:1.9358
# epoch:190 d_loss:0.5508 g_loss:2.0919
# epoch:191 d_loss:0.5921 g_loss:2.0943
# epoch:192 d_loss:0.6438 g_loss:1.8892
# epoch:193 d_loss:0.6274 g_loss:1.7063
# epoch:194 d_loss:0.6125 g_loss:1.6413
# epoch:195 d_loss:0.5752 g_loss:1.5023
# epoch:196 d_loss:0.7844 g_loss:1.4684
# epoch:197 d_loss:0.7154 g_loss:1.4844
# epoch:198 d_loss:0.6500 g_loss:1.4222
# epoch:199 d_loss:0.6576 g_loss:1.3869
# epoch:200 d_loss:0.5757 g_loss:1.5932
# epoch:201 d_loss:0.6259 g_loss:1.5154
# epoch:202 d_loss:0.6116 g_loss:1.5285
# epoch:203 d_loss:0.6056 g_loss:1.2515
# epoch:204 d_loss:0.5673 g_loss:1.5356
# epoch:205 d_loss:0.5341 g_loss:1.4681
# epoch:206 d_loss:0.5460 g_loss:1.4010
# epoch:207 d_loss:0.6079 g_loss:1.2881
# epoch:208 d_loss:0.4875 g_loss:1.3584
# epoch:209 d_loss:0.4430 g_loss:1.5534
# epoch:210 d_loss:0.5059 g_loss:1.2881
# epoch:211 d_loss:0.4442 g_loss:1.1196
# epoch:212 d_loss:0.3716 g_loss:1.1826
# epoch:213 d_loss:0.4558 g_loss:1.1449
# epoch:214 d_loss:0.4854 g_loss:1.2941
# epoch:215 d_loss:0.4398 g_loss:1.2650
# epoch:216 d_loss:0.4318 g_loss:1.4138
# epoch:217 d_loss:0.3368 g_loss:1.2440
# epoch:218 d_loss:0.3662 g_loss:1.4877
# epoch:219 d_loss:0.4870 g_loss:1.4724
# epoch:220 d_loss:0.4660 g_loss:1.4176
# epoch:221 d_loss:0.5457 g_loss:1.2049
# epoch:222 d_loss:0.3892 g_loss:1.5006
# epoch:223 d_loss:0.4587 g_loss:1.5464
# epoch:224 d_loss:0.3777 g_loss:1.3438
# epoch:225 d_loss:0.3765 g_loss:1.6921
# epoch:226 d_loss:0.4688 g_loss:1.5606
# epoch:227 d_loss:0.3774 g_loss:1.6866
# epoch:228 d_loss:0.3342 g_loss:1.5966
# epoch:229 d_loss:0.3390 g_loss:1.7813
# epoch:230 d_loss:0.5011 g_loss:1.4753
# epoch:231 d_loss:0.4711 g_loss:1.4696
# epoch:232 d_loss:0.4732 g_loss:1.5174
# epoch:233 d_loss:0.4127 g_loss:1.8008
# epoch:234 d_loss:0.3902 g_loss:2.0005
# epoch:235 d_loss:0.4371 g_loss:1.8254
# epoch:236 d_loss:0.4770 g_loss:1.7360
# epoch:237 d_loss:0.5043 g_loss:1.3978
# epoch:238 d_loss:0.4377 g_loss:1.7050
# epoch:239 d_loss:0.5011 g_loss:1.9574
# epoch:240 d_loss:0.5340 g_loss:1.7111
# epoch:241 d_loss:0.5267 g_loss:1.9219
# epoch:242 d_loss:0.5542 g_loss:1.9355
# epoch:243 d_loss:0.5908 g_loss:2.1422
# epoch:244 d_loss:0.6772 g_loss:2.0549
# epoch:245 d_loss:0.6822 g_loss:2.1250
# epoch:246 d_loss:0.6732 g_loss:1.9953
# epoch:247 d_loss:0.7074 g_loss:1.8237
# epoch:248 d_loss:0.6154 g_loss:2.0629
# epoch:249 d_loss:0.5347 g_loss:2.2093
# epoch:250 d_loss:0.4694 g_loss:2.0608
# epoch:251 d_loss:0.5383 g_loss:2.3315
# epoch:252 d_loss:0.5798 g_loss:2.0264
# epoch:253 d_loss:0.3916 g_loss:2.3006
# epoch:254 d_loss:0.4791 g_loss:2.0644
# epoch:255 d_loss:0.3409 g_loss:2.3395
# epoch:256 d_loss:0.3953 g_loss:1.7854
# epoch:257 d_loss:0.4976 g_loss:1.6883
# epoch:258 d_loss:0.3871 g_loss:2.3928
# epoch:259 d_loss:0.3414 g_loss:2.5769
# epoch:260 d_loss:0.3508 g_loss:2.5714
# epoch:261 d_loss:0.4284 g_loss:2.3581
# epoch:262 d_loss:0.3682 g_loss:2.3510
# epoch:263 d_loss:0.3582 g_loss:1.7674
# epoch:264 d_loss:0.4293 g_loss:1.6956
# epoch:265 d_loss:0.3290 g_loss:2.2326
# epoch:266 d_loss:0.4646 g_loss:2.5500
# epoch:267 d_loss:0.4196 g_loss:2.5028
# epoch:268 d_loss:0.7964 g_loss:1.9964
# epoch:269 d_loss:0.5270 g_loss:1.6735
# epoch:270 d_loss:0.6349 g_loss:1.3287
# epoch:271 d_loss:0.6758 g_loss:1.5926
# epoch:272 d_loss:0.5418 g_loss:1.6622
# epoch:273 d_loss:0.6903 g_loss:1.5465
# epoch:274 d_loss:0.6735 g_loss:1.7123
# epoch:275 d_loss:0.8514 g_loss:1.5464
# epoch:276 d_loss:0.6329 g_loss:1.4230
# epoch:277 d_loss:0.8605 g_loss:0.9746
# epoch:278 d_loss:0.7186 g_loss:0.9744
# epoch:279 d_loss:0.7769 g_loss:1.1760
# epoch:280 d_loss:0.6134 g_loss:1.0719
# epoch:281 d_loss:0.6268 g_loss:1.2056
# epoch:282 d_loss:0.5175 g_loss:1.2776
# epoch:283 d_loss:0.5066 g_loss:1.5237
# epoch:284 d_loss:0.5505 g_loss:1.4484
# epoch:285 d_loss:0.3466 g_loss:1.3017
# epoch:286 d_loss:0.4730 g_loss:1.4973
# epoch:287 d_loss:0.3270 g_loss:1.8334
# epoch:288 d_loss:0.3441 g_loss:1.5627
# epoch:289 d_loss:0.3170 g_loss:1.8055
# epoch:290 d_loss:0.2856 g_loss:2.2211
# epoch:291 d_loss:0.3040 g_loss:2.2535
# epoch:292 d_loss:0.2315 g_loss:2.3324
# epoch:293 d_loss:0.2231 g_loss:2.1945
# epoch:294 d_loss:0.2930 g_loss:2.3622
# epoch:295 d_loss:0.1852 g_loss:2.5304
# epoch:296 d_loss:0.2479 g_loss:2.4109
# epoch:297 d_loss:0.2783 g_loss:2.3620
# epoch:298 d_loss:0.2970 g_loss:2.4838
# epoch:299 d_loss:0.3309 g_loss:2.6180
# epoch:300 d_loss:0.3059 g_loss:2.7951
# epoch:301 d_loss:0.4201 g_loss:2.7876
# epoch:302 d_loss:0.4069 g_loss:2.3260
# epoch:303 d_loss:0.3057 g_loss:2.3842
# epoch:304 d_loss:0.3631 g_loss:2.0784
# epoch:305 d_loss:0.4479 g_loss:1.8770
# epoch:306 d_loss:0.4655 g_loss:1.7925
# epoch:307 d_loss:0.3509 g_loss:2.0132
# epoch:308 d_loss:0.4933 g_loss:1.8694
# epoch:309 d_loss:0.4929 g_loss:1.8061
# epoch:310 d_loss:0.4673 g_loss:2.1009
# epoch:311 d_loss:0.6099 g_loss:1.8191
# epoch:312 d_loss:0.5204 g_loss:1.9892
# epoch:313 d_loss:0.5289 g_loss:1.7535
# epoch:314 d_loss:0.5422 g_loss:1.7496
# epoch:315 d_loss:0.5339 g_loss:1.7930
# epoch:316 d_loss:0.4544 g_loss:1.5854
# epoch:317 d_loss:0.4189 g_loss:1.5145
# epoch:318 d_loss:0.6450 g_loss:1.7683
# epoch:319 d_loss:0.4995 g_loss:1.6397
# epoch:320 d_loss:0.5338 g_loss:1.7824
# epoch:321 d_loss:0.4055 g_loss:1.9783
# epoch:322 d_loss:0.4713 g_loss:2.0476
# epoch:323 d_loss:0.3786 g_loss:2.1321
# epoch:324 d_loss:0.4143 g_loss:2.4005
# epoch:325 d_loss:0.4245 g_loss:2.0841
# epoch:326 d_loss:0.4316 g_loss:2.7278
# epoch:327 d_loss:0.3406 g_loss:2.8257
# epoch:328 d_loss:0.2921 g_loss:2.8544
# epoch:329 d_loss:0.3907 g_loss:2.6972
# epoch:330 d_loss:0.4582 g_loss:2.2445
# epoch:331 d_loss:0.3726 g_loss:1.9897
# epoch:332 d_loss:0.3606 g_loss:2.2087
# epoch:333 d_loss:0.3337 g_loss:2.8847
# epoch:334 d_loss:0.4985 g_loss:2.6658
# epoch:335 d_loss:0.4007 g_loss:2.8205
# epoch:336 d_loss:0.7342 g_loss:1.9227
# epoch:337 d_loss:0.7583 g_loss:1.4382
# epoch:338 d_loss:0.6235 g_loss:1.9486
# epoch:339 d_loss:0.5479 g_loss:2.1278
# epoch:340 d_loss:0.5747 g_loss:2.0111
# epoch:341 d_loss:0.7739 g_loss:1.2791
# epoch:342 d_loss:0.6091 g_loss:1.2937
# epoch:343 d_loss:0.6560 g_loss:1.4364
# epoch:344 d_loss:0.6233 g_loss:1.7878
# epoch:345 d_loss:0.5924 g_loss:1.9310
# epoch:346 d_loss:0.7871 g_loss:1.6043
# epoch:347 d_loss:0.5405 g_loss:1.4878
# epoch:348 d_loss:0.4295 g_loss:1.4428
# epoch:349 d_loss:0.3846 g_loss:1.9611
# epoch:350 d_loss:0.3938 g_loss:2.0311
# epoch:351 d_loss:0.4074 g_loss:2.1319
# epoch:352 d_loss:0.3898 g_loss:2.3011
# epoch:353 d_loss:0.3352 g_loss:1.8531
# epoch:354 d_loss:0.2992 g_loss:2.1011
# epoch:355 d_loss:0.3249 g_loss:1.8363
# epoch:356 d_loss:0.3156 g_loss:1.9680
# epoch:357 d_loss:0.2576 g_loss:2.0003
# epoch:358 d_loss:0.2800 g_loss:2.0769
# epoch:359 d_loss:0.3297 g_loss:2.3577
# epoch:360 d_loss:0.2612 g_loss:2.6569
# epoch:361 d_loss:0.2814 g_loss:2.4584
# epoch:362 d_loss:0.2397 g_loss:2.7913
# epoch:363 d_loss:0.2432 g_loss:2.5670
# epoch:364 d_loss:0.2875 g_loss:2.2039
# epoch:365 d_loss:0.3091 g_loss:2.4093
# epoch:366 d_loss:0.3411 g_loss:2.0078
# epoch:367 d_loss:0.2867 g_loss:2.0274
# epoch:368 d_loss:0.3528 g_loss:2.1663
# epoch:369 d_loss:0.2965 g_loss:2.2849
# epoch:370 d_loss:0.3049 g_loss:2.2220
# epoch:371 d_loss:0.3417 g_loss:2.1528
# epoch:372 d_loss:0.3700 g_loss:2.3375
# epoch:373 d_loss:0.3977 g_loss:1.8727
# epoch:374 d_loss:0.3779 g_loss:2.2193
# epoch:375 d_loss:0.4766 g_loss:1.9833
# epoch:376 d_loss:0.4226 g_loss:1.7118
# epoch:377 d_loss:0.3799 g_loss:2.1570
# epoch:378 d_loss:0.4573 g_loss:2.1619
# epoch:379 d_loss:0.5361 g_loss:1.9409
# epoch:380 d_loss:0.5368 g_loss:1.8313
# epoch:381 d_loss:0.6434 g_loss:1.9228
# epoch:382 d_loss:0.5553 g_loss:1.6907
# epoch:383 d_loss:0.4644 g_loss:1.9144
# epoch:384 d_loss:0.5407 g_loss:1.8337
# epoch:385 d_loss:0.5346 g_loss:1.7055
# epoch:386 d_loss:0.4679 g_loss:1.9397
# epoch:387 d_loss:0.5556 g_loss:1.7780
# epoch:388 d_loss:0.3475 g_loss:1.8665
# epoch:389 d_loss:0.4645 g_loss:1.9611
# epoch:390 d_loss:0.4449 g_loss:2.0363
# epoch:391 d_loss:0.4084 g_loss:1.7953
# epoch:392 d_loss:0.3343 g_loss:1.9303
# epoch:393 d_loss:0.3111 g_loss:2.5510
# epoch:394 d_loss:0.2488 g_loss:2.0721
# epoch:395 d_loss:0.2843 g_loss:2.4238
# epoch:396 d_loss:0.1883 g_loss:2.9739
# epoch:397 d_loss:0.2690 g_loss:2.8072
# epoch:398 d_loss:0.2806 g_loss:2.8720
# epoch:399 d_loss:0.3106 g_loss:3.0894
# epoch:400 d_loss:0.2175 g_loss:2.7603
# epoch:401 d_loss:0.2252 g_loss:3.0636
# epoch:402 d_loss:0.1624 g_loss:2.8296
# epoch:403 d_loss:0.1932 g_loss:3.0624
# epoch:404 d_loss:0.2126 g_loss:3.3236
# epoch:405 d_loss:0.2015 g_loss:3.4906
# epoch:406 d_loss:0.2070 g_loss:3.0821
# epoch:407 d_loss:0.2826 g_loss:2.8072
# epoch:408 d_loss:0.2498 g_loss:3.1673
# epoch:409 d_loss:0.3016 g_loss:3.1192
# epoch:410 d_loss:0.2534 g_loss:3.2931
# epoch:411 d_loss:0.2407 g_loss:3.3651
# epoch:412 d_loss:0.3700 g_loss:3.1635
# epoch:413 d_loss:0.2573 g_loss:3.2138
# epoch:414 d_loss:0.3445 g_loss:2.0137
# epoch:415 d_loss:0.3669 g_loss:1.7722
# epoch:416 d_loss:0.3956 g_loss:2.6311
# epoch:417 d_loss:0.2835 g_loss:2.7615
# epoch:418 d_loss:0.4571 g_loss:2.5863
# epoch:419 d_loss:0.4444 g_loss:2.0494
# epoch:420 d_loss:0.3225 g_loss:2.2601
# epoch:421 d_loss:0.4851 g_loss:2.2839
# epoch:422 d_loss:0.6290 g_loss:2.1695
# epoch:423 d_loss:0.2824 g_loss:2.1718
# epoch:424 d_loss:0.3838 g_loss:2.3669
# epoch:425 d_loss:0.4031 g_loss:2.1700
# epoch:426 d_loss:0.5731 g_loss:1.5059
# epoch:427 d_loss:0.4555 g_loss:1.3396
# epoch:428 d_loss:0.3914 g_loss:1.6522
# epoch:429 d_loss:0.5023 g_loss:2.0544
# epoch:430 d_loss:0.3337 g_loss:2.9305
# epoch:431 d_loss:0.2756 g_loss:2.6301
# epoch:432 d_loss:0.4133 g_loss:2.3094
# epoch:433 d_loss:0.3913 g_loss:1.5528
# epoch:434 d_loss:0.4072 g_loss:1.4049
# epoch:435 d_loss:0.4228 g_loss:1.6287
# epoch:436 d_loss:0.3236 g_loss:1.9863
# epoch:437 d_loss:0.3093 g_loss:2.5221
# epoch:438 d_loss:0.2935 g_loss:2.6309
# epoch:439 d_loss:0.3514 g_loss:2.2546
# epoch:440 d_loss:0.2952 g_loss:2.3919
# epoch:441 d_loss:0.3340 g_loss:1.6679
# epoch:442 d_loss:0.2855 g_loss:1.6346
# epoch:443 d_loss:0.2839 g_loss:2.0789
# epoch:444 d_loss:0.2910 g_loss:1.9345
# epoch:445 d_loss:0.2961 g_loss:2.3942
# epoch:446 d_loss:0.2421 g_loss:2.5871
# epoch:447 d_loss:0.2460 g_loss:2.8735
# epoch:448 d_loss:0.3094 g_loss:2.7801
# epoch:449 d_loss:0.3143 g_loss:2.4031
# epoch:450 d_loss:0.3223 g_loss:1.8867
# epoch:451 d_loss:0.3041 g_loss:1.4652
# epoch:452 d_loss:0.3531 g_loss:1.8164
# epoch:453 d_loss:0.3979 g_loss:2.3040
# epoch:454 d_loss:0.2694 g_loss:2.9867
# epoch:455 d_loss:0.2620 g_loss:2.8551
# epoch:456 d_loss:0.2293 g_loss:2.7118
# epoch:457 d_loss:0.3187 g_loss:1.9680
# epoch:458 d_loss:0.2121 g_loss:2.2807
# epoch:459 d_loss:0.2538 g_loss:2.2678
# epoch:460 d_loss:0.2164 g_loss:2.2404
# epoch:461 d_loss:0.3974 g_loss:1.9682
# epoch:462 d_loss:0.2754 g_loss:2.1835
# epoch:463 d_loss:0.3796 g_loss:2.2970
# epoch:464 d_loss:0.2953 g_loss:3.0304
# epoch:465 d_loss:0.3075 g_loss:2.3340
# epoch:466 d_loss:0.2502 g_loss:2.2824
# epoch:467 d_loss:0.2901 g_loss:2.2736
# epoch:468 d_loss:0.3037 g_loss:1.9661
# epoch:469 d_loss:0.3241 g_loss:2.4452
# epoch:470 d_loss:0.3610 g_loss:2.3053
# epoch:471 d_loss:0.2971 g_loss:2.2685
# epoch:472 d_loss:0.2567 g_loss:2.3643
# epoch:473 d_loss:0.3761 g_loss:1.9577
# epoch:474 d_loss:0.2814 g_loss:1.8371
# epoch:475 d_loss:0.3498 g_loss:1.9692
# epoch:476 d_loss:0.3854 g_loss:2.0317
# epoch:477 d_loss:0.2600 g_loss:2.2566
# epoch:478 d_loss:0.2379 g_loss:2.5346
# epoch:479 d_loss:0.4617 g_loss:1.7092
# epoch:480 d_loss:0.4060 g_loss:1.5749
# epoch:481 d_loss:0.4302 g_loss:2.2280
# epoch:482 d_loss:0.3107 g_loss:2.8287
# epoch:483 d_loss:0.3174 g_loss:2.9246
# epoch:484 d_loss:0.4148 g_loss:2.6811
# epoch:485 d_loss:0.1961 g_loss:2.2856
# epoch:486 d_loss:0.2122 g_loss:2.4322
# epoch:487 d_loss:0.2280 g_loss:2.4316
# epoch:488 d_loss:0.2745 g_loss:3.2483
# epoch:489 d_loss:0.3094 g_loss:3.2797
# epoch:490 d_loss:0.2965 g_loss:3.1669
# epoch:491 d_loss:0.3029 g_loss:2.5477
# epoch:492 d_loss:0.2300 g_loss:2.1606
# epoch:493 d_loss:0.2842 g_loss:2.5628
# epoch:494 d_loss:0.1344 g_loss:3.3881
# epoch:495 d_loss:0.2211 g_loss:3.2361
# epoch:496 d_loss:0.1994 g_loss:3.2655
# epoch:497 d_loss:0.2611 g_loss:2.9542
# epoch:498 d_loss:0.2473 g_loss:2.7709
# epoch:499 d_loss:0.2062 g_loss:2.4117
# epoch:500 d_loss:0.2703 g_loss:2.3092
# epoch:501 d_loss:0.1907 g_loss:2.6769
# epoch:502 d_loss:0.1718 g_loss:3.1404
# epoch:503 d_loss:0.3247 g_loss:2.9457
# epoch:504 d_loss:0.3090 g_loss:2.7251
# epoch:505 d_loss:0.1340 g_loss:2.8607
# epoch:506 d_loss:0.1569 g_loss:3.3627
# epoch:507 d_loss:0.1268 g_loss:3.6954
# epoch:508 d_loss:0.3109 g_loss:3.7240
# epoch:509 d_loss:0.2108 g_loss:3.6303
# epoch:510 d_loss:0.1546 g_loss:3.4889
# epoch:511 d_loss:0.1108 g_loss:2.8637
# epoch:512 d_loss:0.3084 g_loss:2.5653
# epoch:513 d_loss:0.2990 g_loss:2.9190
# epoch:514 d_loss:0.1599 g_loss:3.6604
# epoch:515 d_loss:0.1814 g_loss:3.5602
# epoch:516 d_loss:0.3412 g_loss:2.6938
# epoch:517 d_loss:0.2565 g_loss:2.9535
# epoch:518 d_loss:0.2359 g_loss:2.6975
# epoch:519 d_loss:0.2639 g_loss:1.8821
# epoch:520 d_loss:0.3087 g_loss:2.4745
# epoch:521 d_loss:0.2313 g_loss:3.4948
# epoch:522 d_loss:0.3409 g_loss:2.4685
# epoch:523 d_loss:0.4453 g_loss:2.6009
# epoch:524 d_loss:0.3013 g_loss:2.9551
# epoch:525 d_loss:0.3791 g_loss:2.5887
# epoch:526 d_loss:0.2978 g_loss:2.6175
# epoch:527 d_loss:0.2330 g_loss:3.1177
# epoch:528 d_loss:0.4467 g_loss:2.5361
# epoch:529 d_loss:0.2625 g_loss:1.7276
# epoch:530 d_loss:0.3128 g_loss:2.0997
# epoch:531 d_loss:0.2114 g_loss:3.0030
# epoch:532 d_loss:0.1376 g_loss:3.4020
# epoch:533 d_loss:0.2534 g_loss:2.9846
# epoch:534 d_loss:0.1820 g_loss:2.4029
# epoch:535 d_loss:0.1442 g_loss:2.4806
# epoch:536 d_loss:0.1962 g_loss:2.7228
# epoch:537 d_loss:0.0875 g_loss:3.9153
# epoch:538 d_loss:0.1976 g_loss:3.9124
# epoch:539 d_loss:0.1627 g_loss:2.7961
# epoch:540 d_loss:0.1279 g_loss:2.3231
# epoch:541 d_loss:0.1500 g_loss:2.4749
# epoch:542 d_loss:0.1611 g_loss:2.6225
# epoch:543 d_loss:0.1725 g_loss:3.3094
# epoch:544 d_loss:0.1008 g_loss:3.2884
# epoch:545 d_loss:0.1423 g_loss:3.9488
# epoch:546 d_loss:0.2306 g_loss:3.5844
# epoch:547 d_loss:0.1289 g_loss:3.2722
# epoch:548 d_loss:0.1833 g_loss:2.9117
# epoch:549 d_loss:0.1796 g_loss:3.0803
# epoch:550 d_loss:0.1059 g_loss:2.8277
# epoch:551 d_loss:0.1117 g_loss:3.5316
# epoch:552 d_loss:0.1533 g_loss:3.4268
# epoch:553 d_loss:0.1371 g_loss:3.0024
# epoch:554 d_loss:0.0946 g_loss:3.3003
# epoch:555 d_loss:0.1367 g_loss:3.1540
# epoch:556 d_loss:0.1664 g_loss:2.9447
# epoch:557 d_loss:0.1570 g_loss:3.2175
# epoch:558 d_loss:0.2604 g_loss:2.9944
# epoch:559 d_loss:0.1326 g_loss:2.5046
# epoch:560 d_loss:0.1773 g_loss:2.5581
# epoch:561 d_loss:0.2195 g_loss:2.5371
# epoch:562 d_loss:0.2211 g_loss:2.8503
# epoch:563 d_loss:0.2653 g_loss:2.6448
# epoch:564 d_loss:0.2550 g_loss:2.6984
# epoch:565 d_loss:0.2217 g_loss:2.6353
# epoch:566 d_loss:0.2617 g_loss:2.1021
# epoch:567 d_loss:0.1848 g_loss:2.1001
# epoch:568 d_loss:0.2025 g_loss:2.6955
# epoch:569 d_loss:0.2139 g_loss:2.3486
# epoch:570 d_loss:0.2961 g_loss:3.8285
# epoch:571 d_loss:0.2743 g_loss:2.9533
# epoch:572 d_loss:0.2003 g_loss:2.3851
# epoch:573 d_loss:0.3372 g_loss:2.0301
# epoch:574 d_loss:0.3177 g_loss:2.3839
# epoch:575 d_loss:0.2787 g_loss:2.2297
# epoch:576 d_loss:0.1740 g_loss:3.5050
# epoch:577 d_loss:0.1621 g_loss:3.3351
# epoch:578 d_loss:0.2168 g_loss:3.3473
# epoch:579 d_loss:0.3604 g_loss:2.3960
# epoch:580 d_loss:0.1492 g_loss:2.5700
# epoch:581 d_loss:0.1138 g_loss:3.5957
# epoch:582 d_loss:0.3074 g_loss:2.5833
# epoch:583 d_loss:0.2069 g_loss:2.6959
# epoch:584 d_loss:0.2065 g_loss:2.3619
# epoch:585 d_loss:0.2840 g_loss:2.7140
# epoch:586 d_loss:0.2206 g_loss:3.0073
# epoch:587 d_loss:0.1177 g_loss:4.0513
# epoch:588 d_loss:0.1877 g_loss:3.9466
# epoch:589 d_loss:0.1684 g_loss:3.2964
# epoch:590 d_loss:0.2377 g_loss:2.8778
# epoch:591 d_loss:0.1901 g_loss:1.9384
# epoch:592 d_loss:0.2761 g_loss:2.3589
# epoch:593 d_loss:0.1408 g_loss:3.9994
# epoch:594 d_loss:0.1290 g_loss:4.7011
# epoch:595 d_loss:0.2975 g_loss:3.6130
# epoch:596 d_loss:0.2220 g_loss:1.8591
# epoch:597 d_loss:0.1888 g_loss:2.1183
# epoch:598 d_loss:0.3201 g_loss:2.2599
# epoch:599 d_loss:0.1168 g_loss:3.0778
# epoch:600 d_loss:0.1207 g_loss:3.4875
# epoch:601 d_loss:0.1351 g_loss:2.8988
# epoch:602 d_loss:0.2737 g_loss:3.4546
# epoch:603 d_loss:0.1159 g_loss:3.5622
# epoch:604 d_loss:0.1944 g_loss:2.9829
# epoch:605 d_loss:0.1488 g_loss:3.3271
# epoch:606 d_loss:0.1216 g_loss:3.2617
# epoch:607 d_loss:0.1813 g_loss:2.7010
# epoch:608 d_loss:0.1893 g_loss:2.4467
# epoch:609 d_loss:0.1053 g_loss:3.0848
# epoch:610 d_loss:0.3461 g_loss:2.0385
# epoch:611 d_loss:0.2551 g_loss:2.8561
# epoch:612 d_loss:0.1849 g_loss:3.0584
# epoch:613 d_loss:0.3641 g_loss:2.2750
# epoch:614 d_loss:0.2859 g_loss:2.7537
# epoch:615 d_loss:0.2196 g_loss:2.3899
# epoch:616 d_loss:0.4565 g_loss:2.5860
# epoch:617 d_loss:0.2476 g_loss:3.3317
# epoch:618 d_loss:0.3205 g_loss:2.3372
# epoch:619 d_loss:0.2409 g_loss:1.8539
# epoch:620 d_loss:0.2840 g_loss:2.2080
# epoch:621 d_loss:0.1849 g_loss:3.3177
# epoch:622 d_loss:0.4658 g_loss:2.8594
# epoch:623 d_loss:0.4395 g_loss:2.3452
# epoch:624 d_loss:0.4171 g_loss:1.5857
# epoch:625 d_loss:0.2919 g_loss:1.9949
# epoch:626 d_loss:0.4166 g_loss:2.1930
# epoch:627 d_loss:0.2550 g_loss:2.8487
# epoch:628 d_loss:0.2988 g_loss:2.9653
# epoch:629 d_loss:0.4796 g_loss:1.4806
# epoch:630 d_loss:0.3443 g_loss:1.6033
# epoch:631 d_loss:0.3130 g_loss:1.7950
# epoch:632 d_loss:0.2410 g_loss:2.9874
# epoch:633 d_loss:0.5782 g_loss:2.1858
# epoch:634 d_loss:0.5701 g_loss:1.1365
# epoch:635 d_loss:0.6680 g_loss:0.8304
# epoch:636 d_loss:0.4228 g_loss:1.2924
# epoch:637 d_loss:0.5704 g_loss:1.1006
# epoch:638 d_loss:0.5801 g_loss:1.4549
# epoch:639 d_loss:0.4978 g_loss:1.9940
# epoch:640 d_loss:0.6993 g_loss:1.7012
# epoch:641 d_loss:0.4746 g_loss:1.5019
# epoch:642 d_loss:0.4233 g_loss:1.5641
# epoch:643 d_loss:0.4396 g_loss:1.7860
# epoch:644 d_loss:0.4875 g_loss:2.2559
# epoch:645 d_loss:0.4325 g_loss:1.9629
# epoch:646 d_loss:0.3850 g_loss:1.9125
# epoch:647 d_loss:0.2908 g_loss:1.7881
# epoch:648 d_loss:0.3929 g_loss:1.9688
# epoch:649 d_loss:0.3280 g_loss:2.7170
# epoch:650 d_loss:0.4277 g_loss:2.5592
# epoch:651 d_loss:0.3572 g_loss:2.3043
# epoch:652 d_loss:0.3057 g_loss:2.2975
# epoch:653 d_loss:0.4028 g_loss:2.4803
# epoch:654 d_loss:0.5570 g_loss:2.7617
# epoch:655 d_loss:0.4773 g_loss:2.2470
# epoch:656 d_loss:0.9949 g_loss:1.9432
# epoch:657 d_loss:1.2043 g_loss:1.0019
# epoch:658 d_loss:0.7036 g_loss:1.2841
# epoch:659 d_loss:0.8112 g_loss:1.3150
# epoch:660 d_loss:0.6648 g_loss:1.1918
# epoch:661 d_loss:1.0406 g_loss:1.3953
# epoch:662 d_loss:0.7415 g_loss:0.8558
# epoch:663 d_loss:0.9412 g_loss:0.5370
# epoch:664 d_loss:0.9760 g_loss:0.6722
# epoch:665 d_loss:0.8440 g_loss:1.0427
# epoch:666 d_loss:1.0032 g_loss:1.3983
# epoch:667 d_loss:0.9169 g_loss:1.5947
# epoch:668 d_loss:0.6648 g_loss:1.7785
# epoch:669 d_loss:0.4239 g_loss:1.8742
# epoch:670 d_loss:0.3294 g_loss:2.2644
# epoch:671 d_loss:0.4616 g_loss:2.3759
# epoch:672 d_loss:0.5379 g_loss:1.9630
# epoch:673 d_loss:0.3867 g_loss:2.0203
# epoch:674 d_loss:0.6261 g_loss:1.9250
# epoch:675 d_loss:1.0198 g_loss:1.8111
# epoch:676 d_loss:0.9954 g_loss:1.6565
# epoch:677 d_loss:1.1470 g_loss:1.6601
# epoch:678 d_loss:0.7229 g_loss:1.9304
# epoch:679 d_loss:0.3811 g_loss:2.9002
# epoch:680 d_loss:0.2672 g_loss:3.6496
# epoch:681 d_loss:0.3052 g_loss:4.2649
# epoch:682 d_loss:0.2016 g_loss:4.2990
# epoch:683 d_loss:0.2393 g_loss:3.4157
# epoch:684 d_loss:0.6421 g_loss:2.9098
# epoch:685 d_loss:0.3419 g_loss:2.2081
# epoch:686 d_loss:0.3492 g_loss:1.6373
# epoch:687 d_loss:0.4702 g_loss:1.5711
# epoch:688 d_loss:1.1177 g_loss:1.2770
# epoch:689 d_loss:1.0086 g_loss:1.0717
# epoch:690 d_loss:0.9489 g_loss:1.0778
# epoch:691 d_loss:0.9038 g_loss:1.3620
# epoch:692 d_loss:1.1803 g_loss:1.4667
# epoch:693 d_loss:0.8479 g_loss:1.1236
# epoch:694 d_loss:0.8121 g_loss:1.0348
# epoch:695 d_loss:0.7693 g_loss:0.9746
# epoch:696 d_loss:0.8029 g_loss:0.8843
# epoch:697 d_loss:0.5676 g_loss:1.4225
# epoch:698 d_loss:0.4079 g_loss:1.8491
# epoch:699 d_loss:0.5102 g_loss:2.2554
# epoch:700 d_loss:0.5198 g_loss:2.0531
# epoch:701 d_loss:0.3622 g_loss:2.2231
# epoch:702 d_loss:0.6285 g_loss:1.9486
# epoch:703 d_loss:0.4203 g_loss:1.9571
# epoch:704 d_loss:0.4166 g_loss:2.2584
# epoch:705 d_loss:0.7037 g_loss:1.8924
# epoch:706 d_loss:0.4671 g_loss:2.8271
# epoch:707 d_loss:0.9686 g_loss:1.9576
# epoch:708 d_loss:1.0292 g_loss:1.6250
# epoch:709 d_loss:1.0183 g_loss:1.3341
# epoch:710 d_loss:1.1528 g_loss:1.0800
# epoch:711 d_loss:0.6069 g_loss:1.7180
# epoch:712 d_loss:0.4789 g_loss:2.2157
# epoch:713 d_loss:0.3887 g_loss:2.4760
# epoch:714 d_loss:0.3339 g_loss:2.8786
# epoch:715 d_loss:0.2394 g_loss:2.9763
# epoch:716 d_loss:0.2429 g_loss:3.1452
# epoch:717 d_loss:0.4424 g_loss:3.6255
# epoch:718 d_loss:0.5251 g_loss:3.3407
# epoch:719 d_loss:0.5543 g_loss:3.5816
# epoch:720 d_loss:0.5321 g_loss:3.0556
# epoch:721 d_loss:0.4249 g_loss:2.2762
# epoch:722 d_loss:0.6955 g_loss:1.6442
# epoch:723 d_loss:0.6836 g_loss:1.2784
# epoch:724 d_loss:0.9666 g_loss:0.9414
# epoch:725 d_loss:0.7926 g_loss:1.0461
# epoch:726 d_loss:1.0591 g_loss:1.0107
# epoch:727 d_loss:0.7794 g_loss:1.1869
# epoch:728 d_loss:0.8893 g_loss:0.8923
# epoch:729 d_loss:0.8705 g_loss:0.8688
# epoch:730 d_loss:0.8221 g_loss:0.7959
# epoch:731 d_loss:0.5430 g_loss:1.0344
# epoch:732 d_loss:0.4883 g_loss:1.4062
# epoch:733 d_loss:0.3712 g_loss:1.5515
# epoch:734 d_loss:0.2904 g_loss:2.0951
# epoch:735 d_loss:0.2568 g_loss:2.6793
# epoch:736 d_loss:0.2572 g_loss:2.6247
# epoch:737 d_loss:0.1496 g_loss:2.5658
# epoch:738 d_loss:0.1663 g_loss:2.9581
# epoch:739 d_loss:0.2843 g_loss:3.0126
# epoch:740 d_loss:0.1404 g_loss:3.2961
# epoch:741 d_loss:0.2952 g_loss:2.9012
# epoch:742 d_loss:0.2942 g_loss:2.8508
# epoch:743 d_loss:0.3061 g_loss:2.6452
# epoch:744 d_loss:0.2642 g_loss:2.2930
# epoch:745 d_loss:0.4724 g_loss:2.2810
# epoch:746 d_loss:0.8785 g_loss:1.9142
# epoch:747 d_loss:0.9182 g_loss:1.7686
# epoch:748 d_loss:0.6426 g_loss:1.6830
# epoch:749 d_loss:0.6132 g_loss:1.7358
# epoch:750 d_loss:0.6365 g_loss:2.0646
# epoch:751 d_loss:0.4486 g_loss:2.2819
# epoch:752 d_loss:0.5753 g_loss:2.2895
# epoch:753 d_loss:0.5465 g_loss:2.1028
# epoch:754 d_loss:0.4851 g_loss:2.0642
# epoch:755 d_loss:0.3535 g_loss:2.0999
# epoch:756 d_loss:0.3703 g_loss:2.3687
# epoch:757 d_loss:0.3354 g_loss:2.0287
# epoch:758 d_loss:0.3231 g_loss:2.3972
# epoch:759 d_loss:0.3411 g_loss:2.5798
# epoch:760 d_loss:0.3255 g_loss:2.5117
# epoch:761 d_loss:0.3604 g_loss:2.6059
# epoch:762 d_loss:0.3697 g_loss:2.7128
# epoch:763 d_loss:0.4521 g_loss:2.5456
# epoch:764 d_loss:0.2694 g_loss:2.2651
# epoch:765 d_loss:0.3977 g_loss:2.2169
# epoch:766 d_loss:0.4868 g_loss:2.0605
# epoch:767 d_loss:0.2889 g_loss:2.1089
# epoch:768 d_loss:0.4036 g_loss:1.6900
# epoch:769 d_loss:0.4050 g_loss:1.8969
# epoch:770 d_loss:0.3141 g_loss:1.8183
# epoch:771 d_loss:0.4077 g_loss:1.8384
# epoch:772 d_loss:0.3798 g_loss:1.7181
# epoch:773 d_loss:0.4115 g_loss:1.9646
# epoch:774 d_loss:0.2918 g_loss:1.7743
# epoch:775 d_loss:0.5935 g_loss:1.5560
# epoch:776 d_loss:0.3997 g_loss:1.4270
# epoch:777 d_loss:0.4257 g_loss:1.6289
# epoch:778 d_loss:0.5172 g_loss:1.2798
# epoch:779 d_loss:0.3509 g_loss:1.4133
# epoch:780 d_loss:0.4647 g_loss:1.3517
# epoch:781 d_loss:0.4457 g_loss:1.4050
# epoch:782 d_loss:0.3471 g_loss:1.5675
# epoch:783 d_loss:0.4944 g_loss:1.1933
# epoch:784 d_loss:0.5074 g_loss:1.4557
# epoch:785 d_loss:0.4430 g_loss:1.3275
# epoch:786 d_loss:0.4024 g_loss:1.3279
# epoch:787 d_loss:0.4446 g_loss:1.1010
# epoch:788 d_loss:0.5418 g_loss:1.2379
# epoch:789 d_loss:0.4212 g_loss:1.7147
# epoch:790 d_loss:0.3443 g_loss:1.6330
# epoch:791 d_loss:0.3702 g_loss:1.8613
# epoch:792 d_loss:0.3483 g_loss:1.6931
# epoch:793 d_loss:0.4362 g_loss:1.7770
# epoch:794 d_loss:0.2779 g_loss:1.6625
# epoch:795 d_loss:0.3930 g_loss:1.4392
# epoch:796 d_loss:0.3835 g_loss:1.4693
# epoch:797 d_loss:0.2884 g_loss:1.7420
# epoch:798 d_loss:0.3222 g_loss:1.6718
# epoch:799 d_loss:0.3207 g_loss:1.9526
# epoch:800 d_loss:0.3256 g_loss:1.7972
# epoch:801 d_loss:0.4105 g_loss:1.6277
# epoch:802 d_loss:0.3216 g_loss:2.0034
# epoch:803 d_loss:0.3307 g_loss:1.5959
# epoch:804 d_loss:0.4181 g_loss:1.7847
# epoch:805 d_loss:0.4583 g_loss:1.5137
# epoch:806 d_loss:0.4786 g_loss:1.6502
