# %% [markdown]
# #### 시드모이드 함수
#
# - y  = 1 / (1 + e<sup>-x</sup>)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid_function(x):
    return 1/(1+np.exp(-x))

x = np.linspace(-5, 5)
y = sigmoid_function(x)

plt.plot(x, y)
plt.show()

# %% [markdown]
# - y<sup>'</sup> = (1 - y) * y

# %% [markdown]
# ### tanh (하이퍼볼릭 탄젠트)
# y = (e<sup>x</sup> - e<sup>-x</sup>) / (e<sup>x</sup> + e<sup>-x</sup>)

# %%
def tanh_function(x):
    return np.tanh(x)

x = np.linspace(-5, 5)
y = tanh_function(x)

plt.plot(x,y)
plt.show()

# %% [markdown]
# ### ReLU (Rectified Linear Unit) 렉티파이드 리니어 유닛
#
# y = if x <= 0 then 0 else x

# %%
def relu_function(x):
    return np.where(x <= 0, 0, x)

x = np.linspace(-5, 5)
y = relu_function(x)

plt.plot(x,y)
plt.show()

# %% [markdown]
# ### Leaky ReLU
#
# - y = if x <= then 0.01x else x
# - x가 음수인 영역에서 아주 작은 기울기를 생성
# - 출력이 0이 되어 더 이상 학습이 진행되지 않는 뉴런이 발생하는 dying ReLu 현상을 피하기 위해 사용

# %%
def leaky_relu_function(x):
    return np.where(x <= 0, 0.01*x, x)
    
x = np.linspace(-5, 5)
y = leaky_relu_function(x)

plt.plot(x,y)
plt.show()

# %% [markdown]
# ### Softmax
# - 입력받은 값을 출력으로 0 ~ 1 사이의 값으로 모두 정규화
# - 출력 값들의 총합은 항상 1
# ![softmax.png](attachment:softmax.png)

# %%
def softmax_function(x):
    return np.exp(x) / np.sum(np.exp(x))

y = softmax_function(np.array([ 1, 2, 3 ]))
print(y)
# Out:
# [0.09003057 0.24472847 0.66524096]

# %% [markdown]
# ## 뉴런
# ![%EB%89%B4%EB%9F%B0.png](attachment:%EB%89%B4%EB%9F%B0.png)

# %% [markdown]
# # 뉴런 모델
# ![neuron%EB%AA%A8%EB%8D%B8.png](attachment:neuron%EB%AA%A8%EB%8D%B8.png)

# %% [markdown]
# ### 단일 신경망 구축
# - 딥러닝에서 가중치(w)와 bias(b)는 임의의 수로 설정 후 학습하는 과정에서 갱신함
# - 지금은 가중치와 bias를 고정하고, 이 값들이 실제 신경망출력에 어떤 의미를 가지는지 확인함
# - 입력으로 단 두개의 값(feature) x,<sub>1</sub>, x<sub>2</sub>
# - 활성화 함수로 시그모이드 함수 사용

# %%
x1 = np.arange(-1.0, 1.0, 0.2)
x2 = np.arange(-1.0, 1.0, 0.2)

Z = np.zeros((10,10))



w_x1 = 2.5
w_x2 = 3.0
bias = 0.1

for i in range(10):
    for j in range(10):
        u = x1[i]*w_x1 + x2[j]*w_x2 + bias
        y = 1/(1 + np.exp(-u))
        Z[j][i] = y
        
plt.imshow(Z, "gray", vmin=0.0, vmax=1.0)
plt.colorbar()
plt.show()

# %%
x1 = np.arange(-1.0, 1.0, 0.2)
x2 = np.arange(-1.0, 1.0, 0.2)

Z = np.zeros((10,10))

W = np.array([2.5, 3.0])

bias = np.array([0.1])

for i in range(10):
    for j in range(10):
        list1 = [x1[i], x2[j]]
        X = np.array(list1)
        u = np.dot(X, W.T) + bias
        y = 1 / (1 + np.exp(-u))
        Z[j][i] = y
        
plt.imshow(Z, "gray", vmin=0.0, vmax=1.0)
plt.colorbar()
plt.show()

# %%
x1 = np.arange(-1.0, 1.0, 0.2)
x2 = np.arange(-1.0, 1.0, 0.2)

Z = np.zeros((10,10))

W = np.array([2.5, 3.0])

bias = np.array([0.1])

for i in range(10):
    for j in range(10):
        list1 = [x1[i], x2[j]]
        X = np.array(list1)
        u = np.dot(X, W.T) + bias
        y = 1 / (1 + np.exp(u))
        Z[j][i] = y
        
plt.imshow(Z, "gray", vmin=0.0, vmax=1.0)
plt.colorbar()
plt.show()

# %%
x1 = np.arange(-1.0, 1.0, 0.2)
x2 = np.arange(-1.0, 1.0, 0.2)

Z = np.zeros((10,10))

W = np.array([0, 3.0])

bias = np.array([0.1])

for i in range(10):
    for j in range(10):
        list1 = [x1[i], x2[j]]
        X = np.array(list1)
        u = np.dot(X, W.T) + bias
        y = 1 / (1 + np.exp(-u))
        Z[j][i] = y
        
plt.imshow(Z, "gray", vmin=0.0, vmax=1.0)
plt.colorbar()
plt.show()

# %%
x1 = np.arange(-1.0, 1.0, 0.2)
x2 = np.arange(-1.0, 1.0, 0.2)

Z = np.zeros((10,10))

W = np.array([2.5, 0])

bias = np.array([0.1])

for i in range(10):
    for j in range(10):
        list1 = [x1[i], x2[j]]
        X = np.array(list1)
        u = np.dot(X, W.T) + bias
        y = 1 / (1 + np.exp(-u))
        Z[j][i] = y
        
plt.imshow(Z, "gray", vmin=0.0, vmax=1.0)
plt.colorbar()
plt.show()

# %%
x1 = np.arange(-1.0, 1.0, 0.2)
x2 = np.arange(-1.0, 1.0, 0.2)

Z = np.zeros((10,10))

W = np.array([2.5, 3.0])

bias = np.array([-2.0])

for i in range(10):
    for j in range(10):
        list1 = [x1[i], x2[j]]
        X = np.array(list1)
        u = np.dot(X, W.T) + bias
        y = 1 / (1 + np.exp(-u))
        Z[j][i] = y
        
plt.imshow(Z, "gray", vmin=0.0, vmax=1.0)
plt.colorbar()

# %%
x1 = np.arange(-1.0, 1.0, 0.2)
x2 = np.arange(-1.0, 1.0, 0.2)

Z = np.zeros((10,10))

W = np.array([2.5, 3.0])

bias = np.array([2.0])

for i in range(10):
    for j in range(10):
        list1 = [x1[i], x2[j]]
        X = np.array(list1)
        u = np.dot(X, W.T) + bias
        y = 1 / (1 + np.exp(-u))
        Z[j][i] = y
        
plt.imshow(Z, "gray", vmin=0.0, vmax=1.0)
plt.colorbar()

# %% [markdown]
# ## 딥러닝 - 한개이상의 은닉층을 포함된 신경망 모델

# %% [markdown]
# - Input Layer 입력 2개, Hidden Layer 노드 2개, Output Layer 노드 1개
# - Hidden Layer 활성화함수 시그모이드,
# - Output Layer 활성화함수 항등함수 (y = x 넣은대로 나옴)

# %%
X = np.arange(-1.0, 1.0, 0.2)
Y = np.arange(-1.0, 1.0, 0.2)

Z = np.zeros((10, 10))

w_im = np.array([[4.0, 4.0], [4.0, 4.0]])
w_mo = np.array([[1.0], [-1.0]])

b_im = np.array([3.0, -3.0])
b_mo = np.array([0.1])

def middle_layer(x, w, b):
    u = np.dot(x, w) + b
    return 1 / (1 + np.exp(-u))

def output_layer(x, w, b):
    u = np.dot(x, w) + b
    return u

for i in range(10):
    for j in range(10):
        inp = np.array([X[i], Y[j]])
        mid = middle_layer(inp, w_im, b_im)
        out = output_layer(mid, w_mo, b_mo)
        
        Z[j][i] = out[0]
        
plt.imshow(Z, "gray", vmin=0.0, vmax=1.0)
plt.colorbar()
plt.show()

# %%
X = np.arange(-1.0, 1.0, 0.2)
Y = np.arange(-1.0, 1.0, 0.2)

Z = np.zeros((10, 10))

w_im = np.array([[-5.0,-5.0], [5.0,-5.0]])
w_mo = np.array([[1.0],[-1.0]])
b_im = np.array([0.0,0.0])
b_mo = np.array([0.0])

def middle_layer(x, w, b):
    u = np.dot(x, w) + b
    return 1 / (1 + np.exp(-u))

def output_layer(x, w, b):
    u = np.dot(x, w) + b
    return u

for i in range(10):
    for j in range(10):
        inp = np.array([X[i], Y[j]])
        mid = middle_layer(inp, w_im, b_im)
        out = output_layer(mid, w_mo, b_mo)
        
        Z[j][i] = out[0]
        
plt.imshow(Z, "gray", vmin=0.0, vmax=1.0)
plt.colorbar()
plt.show()

# %%
X = np.arange(-1.0, 1.0, 0.2)
Y = np.arange(-1.0, 1.0, 0.2)

Z = np.zeros((10, 10))

w_im = np.array([[4.0, 4.0],[4.0,4.0]])
w_mo = np.array([[-1.0],[1.0]])
b_im = np.array([3.0,-3.0])
b_mo = np.array([1.0])

def middle_layer(x, w, b):
    u = np.dot(x, w) + b
    return 1 / (1 + np.exp(-u))

def output_layer(x, w, b):
    u = np.dot(x, w) + b
    return u

for i in range(10):
    for j in range(10):
        inp = np.array([X[i], Y[j]])
        mid = middle_layer(inp, w_im, b_im)
        out = output_layer(mid, w_mo, b_mo)
        
        Z[j][i] = out[0]
        
plt.imshow(Z, "gray", vmin=0.0, vmax=1.0)
plt.colorbar()
plt.show()

# %%
X = np.arange(-1.0, 1.0, 0.2)
Y = np.arange(-1.0, 1.0, 0.2)

Z = np.zeros((10, 10))

w_im = np.array([[-4.0, 4.0],[-4.0,-4.0]])
w_mo = np.array([[1.0],[-1.0]])
b_im = np.array([3.0,-3.0])
b_mo = np.array([0.0])

def middle_layer(x, w, b):
    u = np.dot(x, w) + b
    return 1 / (1 + np.exp(-u))

def output_layer(x, w, b):
    u = np.dot(x, w) + b
    return u

for i in range(10):
    for j in range(10):
        inp = np.array([X[i], Y[j]])
        mid = middle_layer(inp, w_im, b_im)
        out = output_layer(mid, w_mo, b_mo)
        
        Z[j][i] = out[0]
        
plt.imshow(Z, "gray", vmin=0.0, vmax=1.0)
plt.colorbar()
plt.show()
